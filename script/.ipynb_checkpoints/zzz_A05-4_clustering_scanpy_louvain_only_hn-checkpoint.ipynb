# %% [markdown]
# Use Scanpy implementation of Seurat
#
# - https://icb-scanpy-tutorials.readthedocs-hosted.com/en/latest/pbmc3k.html
# - https://satijalab.org/seurat/v1.4/pbmc3k_tutorial.html

# %%
import os, pickle, re, glob, time
import pandas as pd
import numpy as np
np.set_printoptions(precision=2)

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns
from scipy import stats
from collections import Counter

sns.set_style('ticks')
pd.set_option('precision', 2)

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read gene expression

# %%
tmm_df = pd.read_csv('../data/HN_patient_specific/hn_sc_tmm.csv', index_col=0)

# %%
tmm_df.head()
# Out:
#                     RHH2177  RHH2178  RHH2179  RHH2180  RHH2181  RHH2182  \
# gene_id
# ENSG00000000003.10    54.28   129.62   184.29    24.18   152.12     9.29
# ENSG00000000419.8     28.51   121.53   164.62   113.86   114.22    51.24
# ENSG00000000457.9      0.00    26.44     4.27     0.00     0.00     0.00
# ENSG00000000460.12     0.00     0.00    30.61     2.55     0.00    24.02
# ENSG00000000971.11     8.11    74.82     0.00    33.30     0.00     4.86
#
#                     RHH2184  RHH2185  RHH2186  RHH2187  ...  RHO707  RHO708  \
# gene_id                                                 ...
# ENSG00000000003.10    88.18    12.62   186.57    47.41  ...   30.41   89.90
# ENSG00000000419.8     28.20    15.88   297.28    89.74  ...   62.20  224.14
# ENSG00000000457.9      0.00     0.00     0.00     8.18  ...    1.57    2.56
# ENSG00000000460.12     0.00     0.00     0.00    39.09  ...    3.90    1.77
# ENSG00000000971.11     0.00     0.00     0.00    42.44  ...    0.00    0.00
#
#                     RHO709  RHO711  RHO712  RHO713  RHO714  RHO715  RHO716  \
# gene_id
# ENSG00000000003.10  103.19   76.20   20.28   54.14   80.57  103.73   13.37
# ENSG00000000419.8    21.14   31.28   21.21  183.79  216.58  119.42   19.42
# ENSG00000000457.9     1.20    4.24    0.00    0.00    0.00    0.31    0.00
# ENSG00000000460.12    0.00    0.37    0.00    0.67    1.11   43.66    5.22
# ENSG00000000971.11    0.00    0.00    0.00    0.24    1.07    0.00    0.00
#
#                     RHO717
# gene_id
# ENSG00000000003.10   33.00
# ENSG00000000419.8    26.11
# ENSG00000000457.9     4.09
# ENSG00000000460.12    0.00
# ENSG00000000971.11    5.69
#
# [5 rows x 1046 columns]

# %% [markdown]
# ##### map gene_id to gene_name

# %%
gene_df = pd.read_csv('../data/HN_patient_specific/gene.csv', index_col=0)
gene_df.head()
# Out:
#                          gene_type gene_name  \
# gene_id
# ENSG00000000003.10  protein_coding    TSPAN6
# ENSG00000000005.5   protein_coding      TNMD
# ENSG00000000419.8   protein_coding      DPM1
# ENSG00000000457.9   protein_coding     SCYL3
# ENSG00000000460.12  protein_coding  C1orf112
#
#                                                      transcript_id(s)  \
# gene_id
# ENSG00000000003.10  ENST00000373020.4,ENST00000494424.1,ENST000004...
# ENSG00000000005.5                 ENST00000373031.4,ENST00000485971.1
# ENSG00000000419.8   ENST00000371582.4,ENST00000371583.5,ENST000003...
# ENSG00000000457.9   ENST00000367770.1,ENST00000367771.6,ENST000003...
# ENSG00000000460.12  ENST00000286031.6,ENST00000359326.4,ENST000004...
#
#                      length  effective_length
# gene_id
# ENSG00000000003.10  1350.33           1250.33
# ENSG00000000005.5    940.50            840.50
# ENSG00000000419.8    974.71            874.71
# ENSG00000000457.9   3274.40           3174.40
# ENSG00000000460.12  2197.20           2097.20

# %%
gene_id_name_dict = dict(zip(gene_df.index, gene_df['gene_name']))

# %%
# tmm_df.index = [gene_id_name_dict[g] for g in tmm_df.index]
# [(k, v) for k, v in Counter(tmm_df.index).items() if v > 1]

# %%
# tmm_df.loc['Y_RNA']

# %% [markdown]
# ##### cell info

# %%
cell_df = pd.read_csv('../data/HN_patient_specific/cellInfo.csv', index_col=0)
cell_df.head()
# Out:
#         patient_id cell_line_id   origin
# RHH2176      HN120       HN120P  Primary
# RHH2177      HN120       HN120P  Primary
# RHH2178      HN120       HN120P  Primary
# RHH2179      HN120       HN120P  Primary
# RHH2180      HN120       HN120P  Primary

# %% [markdown]
# ### Clustering

# %%
import scanpy as sc
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=72)

import anndata as an
# Out:
# scanpy==1.4.4.post1 anndata==0.6.22.post1 umap==0.3.10 numpy==1.17.4 scipy==1.4.0 pandas==0.25.3 scikit-learn==0.22 statsmodels==0.10.2 python-igraph==0.7.1 louvain==0.6.1

# %%
adata = sc.read_csv('../data/HN_patient_specific/hn_sc_tmm.csv').T
# adata.var_names_make_unique() # no need for gene_id

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1046 × 15464

# %%
# add cell info
adata.obs = pd.merge(adata.obs, cell_df, how='left', left_index=True, right_index=True)

# %% [markdown]
# #### Preprocessing
#
# - cells and genes were already filtered out

# %%
# just add this line to get 'n_genes'
sc.pp.filter_cells(adata, min_genes=200)

# %% [markdown]
# ##### Mito-gene
#
# Citing from “Simple Single Cell” workflows (Lun, McCarthy & Marioni, 2017):
#
# High proportions are indicative of poor-quality cells (Islam et al. 2014; Ilicic et al. 2016), possibly because of loss of cytoplasmic RNA from perforated cells. The reasoning is that mitochondria are larger than individual transcript molecules and less likely to escape through tears in the cell membrane.

# %%
# mito_genes = adata.var_names.str.startswith('MT-')

mito_genes = []

for g in adata.var.index:
    gname = gene_id_name_dict[g]
    if gname.startswith('MT-'):
        mito_genes.append(True)
    else:
        mito_genes.append(False)
        
mito_genes = np.array(mito_genes)
mito_genes
# Out:
# array([False, False, False, ..., False, False, False])

# %%
adata.obs['percent_mito'] = np.sum(
    adata[:, mito_genes].X, axis=1) / np.sum(adata.X, axis=1)
adata.obs['n_counts'] = adata.X.sum(axis=1)

# %%
sc.pl.violin(adata, ['n_genes', 'n_counts', 'percent_mito'],
             jitter=0.4, multi_panel=True)
# Out:
# ... storing 'patient_id' as categorical
# ... storing 'cell_line_id' as categorical
# ... storing 'origin' as categorical

# %%
sc.pl.scatter(adata, x='n_counts', y='percent_mito')
# sc.pl.scatter(adata, x='n_counts', y='n_genes')

# %% [markdown]
# In the tutorial, cutoff for percent_mito is 0.05. However, as we already filtered out some genes, we use cutoff of 0.25 instead.

# %%
adata = adata[adata.obs['percent_mito'] < 0.25, :] # 0.05 in the tutorial
print (adata)
# Out:
# View of AnnData object with n_obs × n_vars = 1034 × 15464
#     obs: 'patient_id', 'cell_line_id', 'origin', 'n_genes', 'percent_mito', 'n_counts'

# %% [markdown]
# ##### log normalize

# %%
sc.pp.log1p(adata)

# %%
adata.raw = adata

# %% [markdown]
# ##### highly variable genes

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.highly_variable_genes(adata)
# Out:
# extracting highly variable genes
#     finished (0:00:01)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
adata = adata[:, adata.var['highly_variable']]

# %% [markdown]
# - skip regress out n_counts and percent_mito
# - skip std clipping

# %% [markdown]
# ##### PCA

# %%
sc.tl.pca(adata, svd_solver='arpack')
sc.pl.pca(adata, color=['patient_id', 'cell_line_id'])
# Out:
# computing PCA with n_comps = 50
# computing PCA on highly variable genes
#     finished (0:00:00)

# %%
sc.pl.pca_variance_ratio(adata, n_pcs=50, log=True)

# %% [markdown]
# ##### neighborhood graph

# %%
sc.pp.neighbors(adata, n_neighbors=10, random_state=0, n_pcs=40)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished: added to `.uns['neighbors']`
#     'distances', distances for each pair of neighbors
#     'connectivities', weighted adjacency matrix (0:00:00)

# %%
sc.tl.umap(adata, random_state=0)
# sc.pl.umap(adata, color=['CST3', 'NKG7', 'PPBP'])
sc.pl.umap(adata, color=['patient_id', 'cell_line_id'])
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# ... storing 'cluster' as categorical
# ... storing 'louvain2' as categorical

# %%
# sc.pl.umap(adata, use_raw=False)

# %% [markdown]
# ##### Clustering

# %%
adata.obs = adata.obs.drop([c for c in adata.obs.columns if 'louvain' in c], axis=1)

sc.tl.louvain(adata, random_state=0)
# Out:
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 11 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.pl.umap(adata, color=['louvain'])

# %%
# sc.tl.tsne(adata)
# sc.pl.tsne(adata, color=['louvain', 'cell_line_id', 'patient_id'])

# %%
sub_cluster_list = []
sub_adata_dict = {}

for i, n in adata.obs.groupby(['louvain'])['n_genes'].count().items():
    if n >= 50:
        sub_adata = adata[adata.obs['louvain'] == i, :]
        sub_adata_dict[i] = sub_adata
        sc.tl.louvain(sub_adata, key_added="louvain2", resolution=0.5)
        sub_cluster_list += [sub_adata.obs[['louvain2']]]
# Out:
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 3 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 1 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 1 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
adata.obs = pd.merge(adata.obs, pd.concat(sub_cluster_list), how='left', left_index=True, right_index=True)

# %%
adata.obs.head()
# Out:
#         patient_id cell_line_id   origin  n_genes  percent_mito  n_counts  \
# RHH2177      HN120       HN120P  Primary     5756          0.09  1.11e+06
# RHH2178      HN120       HN120P  Primary     6667          0.12  9.84e+05
# RHH2179      HN120       HN120P  Primary     7092          0.10  1.03e+06
# RHH2180      HN120       HN120P  Primary     7277          0.11  1.03e+06
# RHH2181      HN120       HN120P  Primary     6387          0.13  9.86e+05
#
#         cluster louvain louvain2
# RHH2177      E1       4        0
# RHH2178      E1       4        0
# RHH2179      E2       4        1
# RHH2180      E1       4        0
# RHH2181      E1       4        0

# %%
adata.obs.groupby(['louvain', 'louvain2'])[['n_counts']].count().dropna()
# Out:
#                   n_counts
# louvain louvain2
# 0       0            138.0
#         1             84.0
# 1       0             54.0
#         1             43.0
# 2       0             48.0
#         1             43.0
# 3       0             66.0
#         1             25.0
# 4       0             59.0
#         1             27.0
# 5       0             38.0
#         1             29.0
#         2             18.0
# 6       0             85.0
# 7       0             49.0
#         1             34.0
# 8       0             46.0
#         1             34.0
# 9       0             69.0

# %%
import string

cluster_list = []

for c, dat in adata.obs.iterrows():
    l = string.ascii_uppercase[int(dat['louvain'])]
    if not pd.isnull(dat['louvain2']):
        l2 = int(dat['louvain2']) + 1
    else:
        l2 = ''
    
    cluster_list += ["{}{}".format(l, l2)]
    
adata.obs.loc[:, 'cluster'] = cluster_list

# %%
adata.obs.groupby('cluster')['n_counts'].count().values
# Out:
# array([138,  84,  54,  43,  48,  43,  66,  25,  59,  27,  38,  29,  18,
#         85,  49,  34,  46,  34,  69,  45])

# %%
len(set(cluster_list)), string.ascii_uppercase[0:10+1]
# Out:
# (20, 'ABCDEFGHIJK')

# %%
adata.obs.groupby(['cell_line_id', 'cluster'])[['n_counts']].count().dropna()
# Out:
#                       n_counts
# cell_line_id cluster
# HN120M       A1            4.0
#              A2           83.0
# HN120P       C2            2.0
#              E1           59.0
#              E2           27.0
# HN137M       F1           38.0
#              F2           29.0
#              F3           17.0
# HN137P       C1           48.0
#              C2           41.0
#              F3            1.0
# HN137P2      A1          134.0
#              A2            1.0
#              K            45.0
# HN148M       B1           54.0
#              B2           37.0
# HN148P       B2            6.0
#              G1           85.0
# HN159M       J1           68.0
# HN159P       H1           49.0
#              H2           34.0
#              J1            1.0
# HN160M       D1           18.0
#              D2           16.0
# HN160P       D1           48.0
#              D2            9.0
# HN182M       I1           46.0
#              I2           34.0

# %%
sc.pl.umap(adata, color=['n_genes', 'cluster', 'cell_line_id'])
# Out:
# ... storing 'cluster' as categorical
# ... storing 'louvain2' as categorical

# %%
sc.pl.umap(sub_adata_dict['3'], color=['louvain2', 'n_genes'])

# %%
adata.obs.to_csv('../preprocessed_data/HN_patient_specific/cell_info_cluster.csv')
