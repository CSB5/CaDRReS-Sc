# %%
import pandas as pd

# %%
existing_df = pd.read_csv('../data/TCGA/unc.edu_PANCAN_IlluminaHiSeq_RNASeqV2.geneExp_whitelisted.tsv', sep='\t', index_col=0)

# %%
existing_df.shape
# Out:
# (20531, 10327)

# %%
existing_df.head()
# Out:
#              TCGA-OR-A5J1-01A-11R-A29S-07  TCGA-OR-A5J2-01A-11R-A29S-07  \
# gene_id
# ?|100130426                        0.0000                        0.0000
# ?|100133144                        3.2661                        2.6815
# ?|100134869                        3.9385                        8.9948
# ?|10357                          149.1350                       81.0777
# ?|10431                         2034.1000                     1304.9300
#
#              TCGA-OR-A5J3-01A-11R-A29S-07  TCGA-OR-A5J5-01A-11R-A29S-07  \
# gene_id
# ?|100130426                        0.0000                        0.0000
# ?|100133144                        1.7301                        0.0000
# ?|100134869                        6.5650                        1.5492
# ?|10357                           86.4879                       53.9117
# ?|10431                         1054.6600                     2350.8900
#
#              TCGA-OR-A5J6-01A-31R-A29S-07  TCGA-OR-A5J7-01A-11R-A29S-07  \
# ...

# %%
existing_df.index = [g.split('|')[0] for g in existing_df.index]

# %%
existing_df.head(1000).tail(10)
# Out:
#         TCGA-OR-A5J1-01A-11R-A29S-07  TCGA-OR-A5J2-01A-11R-A29S-07  \
# ARL10                        14.8895                      160.2470
# ARL11                        21.6138                      175.5470
# ARL13A                        0.0000                        0.0000
# ARL13B                      169.5480                      242.7860
# ARL14                         0.0000                        0.0000
# ARL15                       169.5480                      475.1040
# ARL16                       742.0750                      478.7280
# ARL17A                       70.1921                       54.2343
# ARL17B                        0.0000                        1.3287
# ARL1                       3134.9700                     5377.9300
#
#         TCGA-OR-A5J3-01A-11R-A29S-07  TCGA-OR-A5J5-01A-11R-A29S-07  \
# ARL10                        33.1803                       10.0697
# ARL11                         6.5176                        8.5205
# ...

# %%
existing_df.loc['EGFR']
# Out:
# TCGA-OR-A5J1-01A-11R-A29S-07      193.564
# TCGA-OR-A5J2-01A-11R-A29S-07      126.426
# TCGA-OR-A5J3-01A-11R-A29S-07      635.752
# TCGA-OR-A5J5-01A-11R-A29S-07      363.284
# TCGA-OR-A5J6-01A-31R-A29S-07      377.228
#                                   ...
# TCGA-VQ-AA6I-01A-11R-A414-31    69743.900
# TCGA-VQ-AA6J-01A-11R-A414-31     1482.460
# TCGA-VQ-AA6K-01A-11R-A414-31     1129.960
# TCGA-ZA-A8F6-01A-23R-A36D-31     2586.340
# TCGA-ZQ-A9CR-01A-11R-A39E-31    14754.900
# Name: EGFR, Length: 10327, dtype: float64

# %% [markdown]
# Summary: it is the same as EBPlusPlusAdjustPANCAN_IlluminaHiSeq_RNASeqV2.geneExp.tsv
