# %% [markdown]
# # Clustering based on Seurat paper
#
# Use Scanpy implementation of Seurat
#
# - https://icb-scanpy-tutorials.readthedocs-hosted.com/en/latest/pbmc3k.html
# - https://satijalab.org/seurat/v1.4/pbmc3k_tutorial.html

# %%
import os, pickle, re, glob, time
import pandas as pd
import numpy as np
np.set_printoptions(precision=2)

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns
from scipy import stats
from collections import Counter

sns.set_style('ticks')
pd.set_option('precision', 2)

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
ds_name = 'AS_et_al' # 'AS_et_al', 'AP_et_al', 'SP_et_al'

# %% [markdown]
# ### Read gene expression

# %%
tmm_df = pd.read_csv('../preprocessed_data/scRNAseq/{}_tmm.csv'.format(ds_name), index_col=0)

# %%
tmm_df.head()
# Out:
#        RHH2177  RHH2178  RHH2179  RHH2180  RHH2181  RHH2182  RHH2184  RHH2185  \
# A2ML1     0.00     0.00      0.0     0.00     0.00      0.0     0.00     8.57
# AAAS     94.67   105.15      0.0    32.28     0.00      0.0    16.63   142.95
# AACS      0.00     0.00      0.0     0.00     1.30      0.0     0.00     0.00
# AADAC     0.00    82.12      0.0     0.00     0.00      0.0     0.00     0.00
# AADAT     0.00     0.00      0.0     0.00   107.19      0.0     0.00   150.94
#
#        RHH2186  RHH2187  ...  RHO707  RHO708  RHO709  RHO711  RHO712  RHO713  \
# A2ML1     0.00      0.0  ...     0.0    0.00    0.00    0.00    0.00     0.0
# AAAS    111.08     12.1  ...     0.0    0.00   11.99   16.07    2.38     1.2
# AACS      0.00      0.0  ...     0.0    0.31    6.28   22.08    1.06     0.0
# AADAC     0.00      0.0  ...     0.0    0.00   37.90    0.00    0.00     0.0
# AADAT     0.00      0.0  ...     0.0    0.00    0.00    0.00    0.00     0.0
#
#        RHO714  RHO715  RHO716  RHO717
# A2ML1    0.00    0.00     0.0    0.00
# AAAS     6.34    4.49     0.0    0.00
# AACS     3.47    7.83     0.0    1.87
# AADAC    0.00   21.41     0.0    0.00
# AADAT    0.00    0.00     0.0    0.00
#
# [5 rows x 1046 columns]

# %% [markdown]
# ##### cell info

# %%
cell_df = pd.read_csv('../preprocessed_data/scRNAseq/{}_cell_metadata.csv'.format(ds_name), index_col=0)
cell_df.head()
# Out:
#         sample_id
# RHH2177    HN120P
# RHH2178    HN120P
# RHH2179    HN120P
# RHH2180    HN120P
# RHH2181    HN120P

# %%
if ds_name == 'AS_et_al':
    cell_df.loc[:, 'batch'] = [c[0:3] for c in cell_df.index]
    cell_df.loc[:, 'cell_number'] = [int(c[3:]) for c in cell_df.index]

# %% [markdown]
# ### Clustering

# %%
import scanpy as sc
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=72)

import anndata as an
# Out:
# scanpy==1.4.4.post1 anndata==0.7rc1 umap==0.3.10 numpy==1.16.4 scipy==1.3.0 pandas==0.25.1 scikit-learn==0.21.2 statsmodels==0.10.0

# %%
adata = sc.read_csv('../preprocessed_data/scRNAseq/{}_tpm.csv'.format(ds_name)).T
# adata.var_names_make_unique() # no need for gene_id

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1046 × 15422

# %%
# add cell info
adata.obs = pd.merge(adata.obs, cell_df, how='left', left_index=True, right_index=True)

# %% [markdown]
# #### Preprocessing
#
# - cells and genes were already filtered out

# %%
# just add this line to get 'n_genes'
# sc.pp.filter_cells(adata, min_genes=200)

sc.pp.filter_cells(adata, min_genes=5000)
sc.pp.filter_genes(adata, min_cells=50)
# Out:
# filtered out 5 cells that haveless than 5000 genes expressed

# %% [markdown]
# ##### Mito-gene
#
# Citing from “Simple Single Cell” workflows (Lun, McCarthy & Marioni, 2017):
#
# High proportions are indicative of poor-quality cells (Islam et al. 2014; Ilicic et al. 2016), possibly because of loss of cytoplasmic RNA from perforated cells. The reasoning is that mitochondria are larger than individual transcript molecules and less likely to escape through tears in the cell membrane.

# %%
mito_genes = adata.var_names.str.startswith('MT-')

# %%
adata.obs['percent_mito'] = np.sum(
    adata[:, mito_genes].X, axis=1) / np.sum(adata.X, axis=1)
adata.obs['n_counts'] = adata.X.sum(axis=1)

# %%
sc.pl.violin(adata, ['n_genes', 'n_counts', 'percent_mito'],
             jitter=0.4, multi_panel=True)
# Out:
# ... storing 'sample_id' as categorical
# ... storing 'batch' as categorical

# %%
sc.pl.scatter(adata, x='n_genes', y='percent_mito')
# sc.pl.scatter(adata, x='n_counts', y='n_genes')

# %% [markdown]
# In the tutorial, cutoff for percent_mito is 0.05. However, as we already filtered out some genes, we use cutoff of 0.25 instead.

# %%
adata = adata[adata.obs['percent_mito'] < 0.25, :] # 0.05 in the tutorial
print (adata)
# Out:
# View of AnnData object with n_obs × n_vars = 1031 × 15422
#     obs: 'sample_id', 'batch', 'cell_number', 'n_genes', 'percent_mito', 'n_counts'
#     var: 'n_cells'

# %% [markdown]
# ##### log normalize

# %%
sc.pp.log1p(adata)
# Out:
# /Users/Nok/anaconda3/lib/python3.7/site-packages/scanpy/preprocessing/_simple.py:284: DeprecationWarning: Use is_view instead of isview, isview will be removed in the future.
#   if isinstance(data, AnnData) and data.isview:
# /Users/Nok/anaconda3/lib/python3.7/site-packages/scanpy/utils.py:618: DeprecationWarning: Use is_view instead of isview, isview will be removed in the future.
#   if adata.isview:

# %%
adata.raw = adata

# %% [markdown]
# ##### highly variable genes

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.highly_variable_genes(adata)
# Out:
# extracting highly variable genes
#     finished (0:00:01)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
adata = adata[:, adata.var['highly_variable']]

# %% [markdown]
# - skip regress out n_counts and percent_mito
# - skip std clipping

# %% [markdown]
# ##### PCA

# %%
# adata.obs.loc[:, 'cell_number_RHH'] = adata.obs['cell_number'].values
# adata.obs.loc[adata.obs['cell_number_RHH'] < 1470, 'cell_number_RHH'] = 1200
# adata.obs.loc[adata.obs['cell_number_RHH'] > 2559, 'cell_number_RHH'] = 2600

# %%
sc.tl.pca(adata, svd_solver='arpack')
sc.pl.pca(adata, color=['sample_id'])
# Out:
# computing PCA with n_comps = 50
# computing PCA on highly variable genes
#     finished (0:00:00)

# %%
if ds_name == 'AS_et_al':

    fig, ax = plt.subplots(figsize=(8,6))

    sns.scatterplot(x=adata.obsm['X_pca'][:, 0], y=adata.obsm['X_pca'][:, 1], hue=adata.obs['cell_number_RHH'].values, style=adata.obs['batch'].values, palette='jet', s=50, alpha=0.7, ax=ax)

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
sc.pl.pca_variance_ratio(adata, n_pcs=50, log=True)

# %% [markdown]
# ##### neighborhood graph

# %%
sc.pp.neighbors(adata, n_neighbors=10, random_state=0, n_pcs=40)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 40
# /Users/Nok/anaconda3/lib/python3.7/site-packages/scanpy/neighbors/__init__.py:89: DeprecationWarning: Use is_view instead of isview, isview will be removed in the future.
#   if adata.isview:  # we shouldn't need this here...
#     finished: added to `.uns['neighbors']`
#     'distances', distances for each pair of neighbors
#     'connectivities', weighted adjacency matrix (0:00:02)

# %%
sc.tl.umap(adata, random_state=0)
# sc.pl.umap(adata, color=['CST3', 'NKG7', 'PPBP'])
sc.pl.umap(adata, color=['sample_id'])
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)

# %% [markdown]
# ##### Clustering

# %%
# adata.obs = adata.obs.drop([c for c in adata.obs.columns if 'louvain' in c], axis=1)

sc.tl.louvain(adata, random_state=0)

# %%
sc.pl.umap(adata, color=['louvain'])

# %%
# sc.tl.tsne(adata)
# sc.pl.tsne(adata, color=['louvain', 'cell_line_id', 'patient_id'])

# %%
sub_cluster_list = []
sub_adata_dict = {}

for i, n in adata.obs.groupby(['louvain'])['n_genes'].count().items():
    if n >= 50:
        sub_adata = adata[adata.obs['louvain'] == i, :]
        sub_adata_dict[i] = sub_adata
        sc.tl.louvain(sub_adata, key_added="louvain2", resolution=0.5)
        sub_cluster_list += [sub_adata.obs[['louvain2']]]
# Out:
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 3 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 1 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
# Trying to set attribute `.obs` of view, making a copy.
#     finished: found 2 clusters and added
#     'louvain2', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
adata.obs = pd.merge(adata.obs, pd.concat(sub_cluster_list), how='left', left_index=True, right_index=True)

# %%
adata.obs.head()
# Out:
#         sample_id  n_genes  percent_mito  n_counts louvain louvain2
# RHH2177    HN120P     5754          0.09  1.01e+06       3        0
# RHH2178    HN120P     6658          0.12  9.40e+05       3        0
# RHH2179    HN120P     7089          0.10  1.00e+06       3        1
# RHH2180    HN120P     7273          0.11  9.89e+05       3        0
# RHH2181    HN120P     6381          0.13  9.95e+05       3        0

# %%
adata.obs.groupby(['louvain', 'louvain2'])[['n_counts']].count().dropna()
# Out:
#                   n_counts
# louvain louvain2
# 0       0             82.0
#         1             57.0
# 1       0             68.0
#         1             29.0
# 2       0             68.0
#         1             23.0
# 3       0             59.0
#         1             30.0
# 4       0             54.0
#         1             34.0
# 5       0             37.0
#         1             29.0
#         2             19.0
# 6       0             85.0
# 7       0             49.0
#         1             34.0
# 8       0             50.0
#         1             32.0
# 9       0             40.0
#         1             40.0
# 10      0             44.0
#         1             25.0

# %%
import string

cluster_list = []

for c, dat in adata.obs.iterrows():
    l = string.ascii_uppercase[int(dat['louvain'])]
    if not pd.isnull(dat['louvain2']):
        l2 = int(dat['louvain2']) + 1
    else:
        l2 = ''
    
    cluster_list += ["{}{}".format(l, l2)]
    
adata.obs.loc[:, 'cluster'] = cluster_list

# %%
adata.obs.groupby('cluster')['n_counts'].count().values
# Out:
# array([82, 57, 68, 29, 68, 23, 59, 30, 54, 34, 37, 29, 19, 85, 49, 34, 50,
#        32, 40, 40, 44, 25, 46])

# %%
len(set(cluster_list)), string.ascii_uppercase[0:10+1]
# Out:
# (23, 'ABCDEFGHIJK')

# %%
adata.obs.groupby(['sample_id', 'cluster'])[['n_counts']].count().dropna()
# Out:
#                    n_counts
# sample_id cluster
# HN120M    A1            5.0
#           A2            2.0
#           I1           48.0
#           I2           32.0
# HN120P    D1           58.0
#           D2           30.0
# HN137M    F1           37.0
#           F2           29.0
#           F3           18.0
# HN137P    D1            1.0
#           E1           54.0
#           E2           34.0
#           F3            1.0
# HN137P2   A1           77.0
#           A2           55.0
#           I1            2.0
#           L            46.0
# HN148M    B1           62.0
#           B2           29.0
# HN148P    B1            6.0
#           G1           85.0
# HN159M    K1           43.0
#           K2           25.0
# HN159P    H1           49.0
#           H2           34.0
#           K1            1.0
# HN160M    C1           17.0
#           C2           17.0
# HN160P    C1           51.0
#           C2            6.0
# HN182M    J1           40.0
#           J2           40.0

# %%
sc.pl.umap(adata, color=['n_genes', 'cluster', 'sample_id'])
# Out:
# ... storing 'louvain2' as categorical
# ... storing 'cluster' as categorical

# %%
sc.pl.umap(sub_adata_dict['3'], color=['louvain2', 'n_genes'])

# %%
adata.obs.to_csv('../preprocessed_data/scRNAseq/{}_cluster.csv'.format(ds_name))
